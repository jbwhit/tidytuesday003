# %%
#| hide
from tidytuesday003.core import *

# %% [markdown]
# # tidytuesday003 -- Hockey Goals
#
# > Hockey Goals
#
# From this link: https://github.com/rfordatascience/tidytuesday/blob/master/data/2020/2020-03-03/readme.md

# %% [markdown]
# This file will become your README and also the index of your documentation.

# %% [markdown]
# ## Install

# %% [markdown]
# ```sh
# pip install tidytuesday003
# ```

# %% [markdown]
# ## How to use

# %% [markdown]
# Fill me in please! Don't forget code examples:

# %%
1+1
# Out:
# 2

# %% [markdown]
# # To Do
#
# - !cp /Users/jonathan/Downloads/config_minimal.yaml .
# - missingno “
